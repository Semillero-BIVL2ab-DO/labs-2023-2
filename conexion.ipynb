# %% [markdown]
# # Ejecutando por primera vez

# %%
# conectando con drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# entrar a la carpeta
# %cd '/content/drive/MyDrive'
# Out:
# /content/drive/MyDrive

# %%
# clonamos el repo
# !git clone https://github.com/Semillero-BIVL2ab-DO/labs-2023-2.git
# Out:
# fatal: destination path 'labs-2023-2' already exists and is not an empty directory.

# %% [markdown]
# # Cada vez que quiera actualizar:

# %%
# conectando con drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# entrar a la carpeta
# %cd '/content/drive/MyDrive/labs-2023-2'
# Out:
# /content/drive/MyDrive/labs-2023-2

# %%
# actualizar el repo
# !git pull
# Out:
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 28 (delta 4), reused 28 (delta 4), pack-reused 0
# Unpacking objects: 100% (28/28), 10.70 MiB | 6.62 MiB/s, done.
# From https://github.com/Semillero-BIVL2ab-DO/labs-2023-2
#    c1ea48d..3dc0ac9  main       -> origin/main
# Updating c1ea48d..3dc0ac9
# Fast-forward
#  conexion.ipynb              |   1 +
#  lab1/datos/P1/desktop.ini   |   2 ++
#  lab1/datos/P2/desktop.ini   |   2 ++
#  lab1/datos/P3/desktop.ini   |   2 ++
#  lab1/datos/P4/desktop.ini   |   2 ++
#  lab1/datos/desktop.ini      |   2 ++
#  lab2/datos/015.jpg          | Bin 0 -> 1048098 bytes
#  lab2/datos/015.png          | Bin 0 -> 11422 bytes
#  lab2/datos/035.jpg          | Bin 0 -> 679318 bytes
#  lab2/datos/062.jpg          | Bin 0 -> 934110 bytes
#  lab2/datos/193.jpg          | Bin 0 -> 701440 bytes
#  lab2/datos/378.jpg          | Bin 0 -> 689824 bytes
# ...
